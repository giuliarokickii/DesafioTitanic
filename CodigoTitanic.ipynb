# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
def transformar_sexo(valor):
    if valor == 'female':
        return 1
    else:
        return 0

# %%
train['Sex_binario'] = train['Sex'].map(transformar_sexo)
test['Sex_binario'] = test['Sex'].map(transformar_sexo)

# %%
variaveis = ['Sex_binario', 'Age']

# %%
X_train = train[variaveis].fillna(-1)
y_train = train['Survived']

# %%
modelo = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)
modelo.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=0)

# %%
X_test = test[variaveis].fillna(-1)
predictions = modelo.predict(X_test)

# %%
test['Survived'] = predictions

# %%
predictions_series = pd.Series(predictions, index=test['PassengerId'], name='Survived')
predictions_series.to_csv("primeiro_modelo.csv", header=True)

# %%
styled = test.style.applymap(
    lambda x: 'background-color: lightgreen' if x == 1 else '',
    subset=['Survived']
)

styled = styled.set_properties(**{
    'background-color': 'lightgray',
    'color': 'black',
    'border-color': 'gray'
})

# %%
styled
# Out:
# <style type="text/css">
# ...
